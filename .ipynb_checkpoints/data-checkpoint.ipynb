# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("13-car_evaluation.csv")

# %%
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
df.columns
# Out:
# Index(['vhigh', 'vhigh.1', '2', '2.1', 'small', 'low', 'unacc'], dtype='object')

# %%
df.shape
# Out:
# (1727, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   vhigh    1727 non-null   object
#  1   vhigh.1  1727 non-null   object
#  2   2        1727 non-null   object
#  3   2.1      1727 non-null   object
#  4   small    1727 non-null   object
#  5   low      1727 non-null   object
#  6   unacc    1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
col_names=["buying","maint","doors","persons","lug_boot","safety","class"]

# %%
df.columns=col_names

# %%
df.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    med  unacc
# 1  vhigh  vhigh     2       2    small   high  unacc
# 2  vhigh  vhigh     2       2      med    low  unacc
# 3  vhigh  vhigh     2       2      med    med  unacc
# 4  vhigh  vhigh     2       2      med   high  unacc

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# buying
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# maint
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# doors
# 3        432
# 4        432
# 5more    432
# 2        431
# Name: count, dtype: int64
# persons
# 4       576
# more    576
# 2       575
# Name: count, dtype: int64
# lug_boot
# med      576
# big      576
# small    575
# Name: count, dtype: int64
# safety
# med     576
# high    576
# low     575
# Name: count, dtype: int64
# class
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
df["doors"].unique()
# Out:
# array(['2', '3', '4', '5more'], dtype=object)

# %%
df["doors"]=df["doors"].replace("5more",5)

# %%
df["doors"].unique()
# Out:
# array(['2', '3', '4', 5], dtype=object)

# %%
df["doors"]=df["doors"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1727 non-null   object
#  1   maint     1727 non-null   object
#  2   doors     1727 non-null   int64
#  3   persons   1727 non-null   object
#  4   lug_boot  1727 non-null   object
#  5   safety    1727 non-null   object
#  6   class     1727 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 94.6+ KB

# %%
df["persons"].unique()
# Out:
# array(['2', '4', 'more'], dtype=object)

# %%
df["persons"]=df["persons"].replace("more",5)

# %%
df["persons"].value_counts()
# Out:
# persons
# 4    576
# 5    576
# 2    575
# Name: count, dtype: int64

# %%
df["persons"]=df["persons"].astype(int)

# %%
df["persons"].unique()
# Out:
# array([2, 4, 5])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1727 non-null   object
#  1   maint     1727 non-null   object
#  2   doors     1727 non-null   int64
#  3   persons   1727 non-null   int64
#  4   lug_boot  1727 non-null   object
#  5   safety    1727 non-null   object
#  6   class     1727 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 94.6+ KB

# %%
sns.scatterplot(x=df["buying"],y=df["maint"],hue=df["class"])
# Out:
# <Axes: xlabel='buying', ylabel='maint'>

# %%
sns.scatterplot(x=df["lug_boot"],y=df["safety"],hue=df["class"])
# Out:
# <Axes: xlabel='lug_boot', ylabel='safety'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1727 non-null   object
#  1   maint     1727 non-null   object
#  2   doors     1727 non-null   int64
#  3   persons   1727 non-null   int64
#  4   lug_boot  1727 non-null   object
#  5   safety    1727 non-null   object
#  6   class     1727 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 94.6+ KB

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='class')
plt.title('Target Veriable')
plt.show()

# %%
plt.figure(figsize=(10, 6))
# buying (alım fiyatı) özelliğini incele
sns.countplot(data=df, x='buying', hue='class', palette='cubehelix')
plt.title('the effect of purchase price on classification')
plt.show()

# %%
X=df.drop("class",axis=1)
y=df["class"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=15)

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
categorical_cols=["buying","maint","lug_boot","safety"]
numeric_col=["doors","persons"]
ordinal_encoder=OrdinalEncoder(categories=[
    ["low","med","high","vhigh"],
    ["low","med","high","vhigh",],
    ["small","med","big"],
    ["low","med","high"]
])
preprocessor=ColumnTransformer(transformers=[
    ("transformation_name",ordinal_encoder,categorical_cols)
    ##  örnek ("transformation_name",label_encoder,categorical_cols), gibi diğer kolonlar içinde yapılabilir
    
],remainder="passthrough")
X_train_transformed=preprocessor.fit_transform(X_train)
X_test_transformed=preprocessor.transform(X_test)

# %%
##for col in categorical_cols:
  ##  print(df[col].value_counts())

# %%
pd.DataFrame(X_train_transformed)[5].unique()
# Out:
# array([2., 4., 5.])

# %%
## model start

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_model=DecisionTreeClassifier(criterion="gini",max_depth=3,random_state=0)

# %%
tree_model.fit(X_train_transformed,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
y_pred=tree_model.predict(X_test_transformed)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print("accuarcy score:",accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuarcy score: 0.7893518518518519
# [[ 44   0  49   0]
#  [ 19   0   0   0]
#  [  8   0 297   0]
#  [ 15   0   0   0]]
#               precision    recall  f1-score   support
#
#          acc       0.51      0.47      0.49        93
#         good       0.00      0.00      0.00        19
#        unacc       0.86      0.97      0.91       305
#        vgood       0.00      0.00      0.00        15
#
#     accuracy                           0.79       432
#    macro avg       0.34      0.36      0.35       432
# weighted avg       0.72      0.79      0.75       432
# C:\Users\ahmet\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ahmet\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ahmet\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
plt.figure(figsize=(13,8))
from sklearn import tree
column_names=categorical_cols + numeric_col
tree.plot_tree(tree_model.fit(X_train_transformed,y_train),feature_names=column_names)
# Out:
# [Text(0.3333333333333333, 0.875, 'safety <= 0.5\ngini = 0.459\nsamples = 1295\nvalue = [291, 50, 904, 50]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 436\nvalue = [0, 0, 436, 0]'),
#  Text(0.25, 0.75, 'True  '),
#  Text(0.5, 0.625, 'persons <= 3.0\ngini = 0.582\nsamples = 859\nvalue = [291.0, 50.0, 468.0, 50.0]'),
#  Text(0.41666666666666663, 0.75, '  False'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 281\nvalue = [0, 0, 281, 0]'),
#  Text(0.6666666666666666, 0.375, 'buying <= 1.5\ngini = 0.627\nsamples = 578\nvalue = [291.0, 50.0, 187.0, 50.0]'),
#  Text(0.5, 0.125, 'gini = 0.639\nsamples = 298\nvalue = [160, 50, 38, 50]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.498\nsamples = 280\nvalue = [131, 0, 149, 0]')]

# %%
param = {
    "criterion" : ["gini", "entropy", "log_loss"],
    "splitter" : ["best", "random"],
    "max_depth" : [1,2,3,4,5,15,None],
    "max_features" : ["sqrt", "log2", None]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid= GridSearchCV(estimator = DecisionTreeClassifier(), param_grid=param, cv=5,scoring="accuracy")

# %%
import warnings
warnings.filterwarnings("ignore")
grid.fit(X_train_transformed, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5, 15, None],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
grid.best_score_
# Out:
# np.float64(0.972972972972973)

# %%
tree_model_new.best_params_
# Out:
# {'criterion': 'log_loss',
#  'max_depth': 15,
#  'max_features': None,
#  'splitter': 'best'}

# %%
y_pred=grid.predict(X_test_transformed)

# %%
grid = DecisionTreeClassifier(criterion="entropy",max_depth=None, max_features=None, splitter="best")

# %%
tree_model_new = DecisionTreeClassifier(criterion="entropy",max_depth=None, max_features=None, splitter="best")

# %%
tree_model_new.fit(X_train_transformed, y_train)
y_pred = tree_model_new.predict(X_test_transformed)
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.9791666666666666
# [[ 91   0   1   1]
#  [  3  16   0   0]
#  [  4   0 301   0]
#  [  0   0   0  15]]
#               precision    recall  f1-score   support
#
#          acc       0.93      0.98      0.95        93
#         good       1.00      0.84      0.91        19
#        unacc       1.00      0.99      0.99       305
#        vgood       0.94      1.00      0.97        15
#
#     accuracy                           0.98       432
#    macro avg       0.97      0.95      0.96       432
# weighted avg       0.98      0.98      0.98       432

# %%
tree.plot_tree(tree_model_new.fit(X_train_transformed, y_train),feature_names=column_names)
# Out:
# [Text(0.5971283783783784, 0.9615384615384616, 'safety <= 0.5\nentropy = 1.209\nsamples = 1295\nvalue = [291, 50, 904, 50]'),
#  Text(0.5836148648648649, 0.8846153846153846, 'entropy = 0.0\nsamples = 436\nvalue = [0, 0, 436, 0]'),
#  Text(0.5903716216216217, 0.9230769230769231, 'True  '),
#  Text(0.6106418918918919, 0.8846153846153846, 'persons <= 3.0\nentropy = 1.484\nsamples = 859\nvalue = [291.0, 50.0, 468.0, 50.0]'),
#  Text(0.6038851351351351, 0.9230769230769231, '  False'),
#  Text(0.5971283783783784, 0.8076923076923077, 'entropy = 0.0\nsamples = 281\nvalue = [0, 0, 281, 0]'),
#  Text(0.6241554054054054, 0.8076923076923077, 'buying <= 1.5\nentropy = 1.636\nsamples = 578\nvalue = [291.0, 50.0, 187.0, 50.0]'),
#  Text(0.3902027027027027, 0.7307692307692307, 'maint <= 1.5\nentropy = 1.725\nsamples = 298\nvalue = [160, 50, 38, 50]'),
#  Text(0.19932432432432431, 0.6538461538461539, 'safety <= 1.5\nentropy = 1.797\nsamples = 148\nvalue = [49, 50, 8, 41]'),
#  Text(0.08108108108108109, 0.5769230769230769, 'lug_boot <= 0.5\nentropy = 1.222\nsamples = 71\nvalue = [41, 26, 4, 0]'),
#  Text(0.04054054054054054, 0.5, 'doors <= 2.5\nentropy = 0.65\nsamples = 24\nvalue = [20, 0, 4, 0]'),
#  Text(0.02702702702702703, 0.4230769230769231, 'persons <= 4.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 0, 4, 0]'),
#  Text(0.013513513513513514, 0.34615384615384615, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.04054054054054054, 0.34615384615384615, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.05405405405405406, 0.4230769230769231, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0, 0, 0]'),
#  Text(0.12162162162162163, 0.5, 'maint <= 0.5\nentropy = 0.992\nsamples = 47\nvalue = [21, 26, 0, 0]'),
#  Text(0.08108108108108109, 0.4230769230769231, 'lug_boot <= 1.5\nentropy = 0.702\nsamples = 21\nvalue = [4, 17, 0, 0]'),
#  Text(0.06756756756756757, 0.34615384615384615, 'doors <= 2.5\nentropy = 0.971\nsamples = 10\nvalue = [4, 6, 0, 0]'),
#  Text(0.05405405405405406, 0.2692307692307692, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.08108108108108109, 0.2692307692307692, 'persons <= 4.5\nentropy = 0.592\nsamples = 7\nvalue = [1, 6, 0, 0]'),
#  Text(0.06756756756756757, 0.19230769230769232, 'doors <= 4.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2, 0, 0]'),
#  Text(0.05405405405405406, 0.11538461538461539, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.08108108108108109, 0.11538461538461539, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.0945945945945946, 0.19230769230769232, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.0945945945945946, 0.34615384615384615, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11, 0, 0]'),
#  Text(0.16216216216216217, 0.4230769230769231, 'buying <= 0.5\nentropy = 0.931\nsamples = 26\nvalue = [17, 9, 0, 0]'),
#  Text(0.14864864864864866, 0.34615384615384615, 'doors <= 3.5\nentropy = 0.811\nsamples = 12\nvalue = [3, 9, 0, 0]'),
#  Text(0.13513513513513514, 0.2692307692307692, 'lug_boot <= 1.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 3, 0, 0]'),
#  Text(0.12162162162162163, 0.19230769230769232, 'doors <= 2.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1, 0, 0]'),
#  Text(0.10810810810810811, 0.11538461538461539, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.13513513513513514, 0.11538461538461539, 'persons <= 4.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.12162162162162163, 0.038461538461538464, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.14864864864864866, 0.038461538461538464, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.14864864864864866, 0.19230769230769232, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.16216216216216217, 0.2692307692307692, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]'),
#  Text(0.17567567567567569, 0.34615384615384615, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0, 0, 0]'),
#  Text(0.31756756756756754, 0.5769230769230769, 'lug_boot <= 0.5\nentropy = 1.569\nsamples = 77\nvalue = [8, 24, 4, 41]'),
#  Text(0.24324324324324326, 0.5, 'doors <= 2.5\nentropy = 1.249\nsamples = 27\nvalue = [5, 18, 4, 0]'),
#  Text(0.21621621621621623, 0.4230769230769231, 'persons <= 4.5\nentropy = 1.379\nsamples = 7\nvalue = [1, 2, 4, 0]'),
#  Text(0.20270270270270271, 0.34615384615384615, 'maint <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2, 0, 0]'),
#  Text(0.1891891891891892, 0.2692307692307692, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.21621621621621623, 0.2692307692307692, 'buying <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.20270270270270271, 0.19230769230769232, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.22972972972972974, 0.19230769230769232, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.22972972972972974, 0.34615384615384615, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.2702702702702703, 0.4230769230769231, 'maint <= 0.5\nentropy = 0.722\nsamples = 20\nvalue = [4, 16, 0, 0]'),
#  Text(0.25675675675675674, 0.34615384615384615, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11, 0, 0]'),
#  Text(0.28378378378378377, 0.34615384615384615, 'buying <= 0.5\nentropy = 0.991\nsamples = 9\nvalue = [4, 5, 0, 0]'),
#  Text(0.2702702702702703, 0.2692307692307692, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]'),
#  Text(0.2972972972972973, 0.2692307692307692, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]'),
#  Text(0.3918918918918919, 0.5, 'lug_boot <= 1.5\nentropy = 0.845\nsamples = 50\nvalue = [3, 6, 0, 41]'),
#  Text(0.3783783783783784, 0.4230769230769231, 'doors <= 2.5\nentropy = 1.248\nsamples = 26\nvalue = [3, 6, 0, 17]'),
#  Text(0.33783783783783783, 0.34615384615384615, 'buying <= 0.5\nentropy = 0.863\nsamples = 7\nvalue = [2, 5, 0, 0]'),
#  Text(0.32432432432432434, 0.2692307692307692, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.35135135135135137, 0.2692307692307692, 'maint <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1, 0, 0]'),
#  Text(0.33783783783783783, 0.19230769230769232, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.36486486486486486, 0.19230769230769232, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.4189189189189189, 0.34615384615384615, 'doors <= 3.5\nentropy = 0.591\nsamples = 19\nvalue = [1, 1, 0, 17]'),
#  Text(0.40540540540540543, 0.2692307692307692, 'persons <= 4.5\nentropy = 1.252\nsamples = 6\nvalue = [1, 1, 0, 4]'),
#  Text(0.3918918918918919, 0.19230769230769232, 'buying <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.3783783783783784, 0.11538461538461539, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.40540540540540543, 0.11538461538461539, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.4189189189189189, 0.19230769230769232, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.43243243243243246, 0.2692307692307692, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13]'),
#  Text(0.40540540540540543, 0.4230769230769231, 'entropy = 0.0\nsamples = 24\nvalue = [0, 0, 0, 24]'),
#  Text(0.581081081081081, 0.6538461538461539, 'safety <= 1.5\nentropy = 1.029\nsamples = 150\nvalue = [111, 0, 30, 9]'),
#  Text(0.5, 0.5769230769230769, 'lug_boot <= 0.5\nentropy = 0.938\nsamples = 79\nvalue = [51, 0, 28, 0]'),
#  Text(0.47297297297297297, 0.5, 'buying <= 0.5\nentropy = 0.65\nsamples = 24\nvalue = [4, 0, 20, 0]'),
#  Text(0.4594594594594595, 0.4230769230769231, 'maint <= 2.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 0, 4, 0]'),
#  Text(0.44594594594594594, 0.34615384615384615, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]'),
#  Text(0.47297297297297297, 0.34615384615384615, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.4864864864864865, 0.4230769230769231, 'entropy = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0]'),
#  Text(0.527027027027027, 0.5, 'doors <= 3.5\nentropy = 0.598\nsamples = 55\nvalue = [47, 0, 8, 0]'),
#  Text(0.5135135135135135, 0.4230769230769231, 'lug_boot <= 1.5\nentropy = 0.89\nsamples = 26\nvalue = [18, 0, 8, 0]'),
#  Text(0.5, 0.34615384615384615, 'buying <= 0.5\nentropy = 0.961\nsamples = 13\nvalue = [5, 0, 8, 0]'),
#  Text(0.47297297297297297, 0.2692307692307692, 'maint <= 2.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 0, 2, 0]'),
#  Text(0.4594594594594595, 0.19230769230769232, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.4864864864864865, 0.19230769230769232, 'persons <= 4.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 0, 2, 0]'),
#  Text(0.47297297297297297, 0.11538461538461539, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.5, 0.11538461538461539, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.527027027027027, 0.2692307692307692, 'doors <= 2.5\nentropy = 0.592\nsamples = 7\nvalue = [1, 0, 6, 0]'),
#  Text(0.5135135135135135, 0.19230769230769232, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.5405405405405406, 0.19230769230769232, 'persons <= 4.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 0, 2, 0]'),
#  Text(0.527027027027027, 0.11538461538461539, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.5540540540540541, 0.11538461538461539, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.527027027027027, 0.34615384615384615, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0, 0, 0]'),
#  Text(0.5405405405405406, 0.4230769230769231, 'entropy = 0.0\nsamples = 29\nvalue = [29, 0, 0, 0]'),
#  Text(0.6621621621621622, 0.5769230769230769, 'maint <= 2.5\nentropy = 0.728\nsamples = 71\nvalue = [60, 0, 2, 9]'),
#  Text(0.6216216216216216, 0.5, 'buying <= 0.5\nentropy = 0.822\nsamples = 35\nvalue = [26, 0, 0, 9]'),
#  Text(0.6081081081081081, 0.4230769230769231, 'lug_boot <= 0.5\nentropy = 0.998\nsamples = 17\nvalue = [8, 0, 0, 9]'),
#  Text(0.5945945945945946, 0.34615384615384615, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.6216216216216216, 0.34615384615384615, 'doors <= 3.5\nentropy = 0.684\nsamples = 11\nvalue = [2, 0, 0, 9]'),
#  Text(0.6081081081081081, 0.2692307692307692, 'persons <= 4.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 0, 0, 3]'),
#  Text(0.5945945945945946, 0.19230769230769232, 'lug_boot <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 0, 1]'),
#  Text(0.581081081081081, 0.11538461538461539, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.6081081081081081, 0.11538461538461539, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.6216216216216216, 0.19230769230769232, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.6351351351351351, 0.2692307692307692, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]'),
#  Text(0.6351351351351351, 0.4230769230769231, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0, 0, 0]'),
#  Text(0.7027027027027027, 0.5, 'doors <= 2.5\nentropy = 0.31\nsamples = 36\nvalue = [34, 0, 2, 0]'),
#  Text(0.6891891891891891, 0.4230769230769231, 'lug_boot <= 0.5\nentropy = 0.764\nsamples = 9\nvalue = [7, 0, 2, 0]'),
#  Text(0.6756756756756757, 0.34615384615384615, 'persons <= 4.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 0, 2, 0]'),
#  Text(0.6621621621621622, 0.2692307692307692, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.6891891891891891, 0.2692307692307692, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.7027027027027027, 0.34615384615384615, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]'),
#  Text(0.7162162162162162, 0.4230769230769231, 'entropy = 0.0\nsamples = 27\nvalue = [27, 0, 0, 0]'),
#  Text(0.8581081081081081, 0.7307692307692307, 'maint <= 2.5\nentropy = 0.997\nsamples = 280\nvalue = [131, 0, 149, 0]'),
#  Text(0.8445945945945946, 0.6538461538461539, 'lug_boot <= 0.5\nentropy = 0.943\nsamples = 205\nvalue = [131, 0, 74, 0]'),
#  Text(0.7567567567567568, 0.5769230769230769, 'safety <= 1.5\nentropy = 0.913\nsamples = 67\nvalue = [22, 0, 45, 0]'),
#  Text(0.7432432432432432, 0.5, 'entropy = 0.0\nsamples = 33\nvalue = [0, 0, 33, 0]'),
#  Text(0.7702702702702703, 0.5, 'doors <= 2.5\nentropy = 0.937\nsamples = 34\nvalue = [22, 0, 12, 0]'),
#  Text(0.7432432432432432, 0.4230769230769231, 'persons <= 4.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 0, 7, 0]'),
#  Text(0.7297297297297297, 0.34615384615384615, 'maint <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 1, 0]'),
#  Text(0.7162162162162162, 0.2692307692307692, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.7432432432432432, 0.2692307692307692, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.7567567567567568, 0.34615384615384615, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0]'),
#  Text(0.7972972972972973, 0.4230769230769231, 'buying <= 2.5\nentropy = 0.722\nsamples = 25\nvalue = [20, 0, 5, 0]'),
#  Text(0.7837837837837838, 0.34615384615384615, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0, 0, 0]'),
#  Text(0.8108108108108109, 0.34615384615384615, 'maint <= 1.5\nentropy = 0.994\nsamples = 11\nvalue = [6, 0, 5, 0]'),
#  Text(0.7972972972972973, 0.2692307692307692, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.8243243243243243, 0.2692307692307692, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]'),
#  Text(0.9324324324324325, 0.5769230769230769, 'maint <= 1.5\nentropy = 0.742\nsamples = 138\nvalue = [109, 0, 29, 0]'),
#  Text(0.8918918918918919, 0.5, 'lug_boot <= 1.5\nentropy = 0.391\nsamples = 91\nvalue = [84, 0, 7, 0]'),
#  Text(0.8783783783783784, 0.4230769230769231, 'safety <= 1.5\nentropy = 0.659\nsamples = 41\nvalue = [34.0, 0.0, 7.0, 0.0]'),
#  Text(0.8648648648648649, 0.34615384615384615, 'doors <= 3.5\nentropy = 0.949\nsamples = 19\nvalue = [12, 0, 7, 0]'),
#  Text(0.8513513513513513, 0.2692307692307692, 'persons <= 4.5\nentropy = 0.881\nsamples = 10\nvalue = [3, 0, 7, 0]'),
#  Text(0.8378378378378378, 0.19230769230769232, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]'),
#  Text(0.8648648648648649, 0.19230769230769232, 'doors <= 2.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 0, 2, 0]'),
#  Text(0.8513513513513513, 0.11538461538461539, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.8783783783783784, 0.11538461538461539, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.8783783783783784, 0.2692307692307692, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0, 0, 0]'),
#  Text(0.8918918918918919, 0.34615384615384615, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0, 0, 0]'),
#  Text(0.9054054054054054, 0.4230769230769231, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0, 0]'),
#  Text(0.972972972972973, 0.5, 'buying <= 2.5\nentropy = 0.997\nsamples = 47\nvalue = [25, 0, 22, 0]'),
#  Text(0.9594594594594594, 0.4230769230769231, 'lug_boot <= 1.5\nentropy = 0.381\nsamples = 27\nvalue = [25, 0, 2, 0]'),
#  Text(0.9459459459459459, 0.34615384615384615, 'safety <= 1.5\nentropy = 0.65\nsamples = 12\nvalue = [10, 0, 2, 0]'),
#  Text(0.9324324324324325, 0.2692307692307692, 'doors <= 3.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 0, 2, 0]'),
#  Text(0.918918918918919, 0.19230769230769232, 'doors <= 2.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 0, 2, 0]'),
#  Text(0.9054054054054054, 0.11538461538461539, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.9324324324324325, 0.11538461538461539, 'persons <= 4.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 0, 1, 0]'),
#  Text(0.918918918918919, 0.038461538461538464, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.9459459459459459, 0.038461538461538464, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.9459459459459459, 0.19230769230769232, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.9594594594594594, 0.2692307692307692, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.972972972972973, 0.34615384615384615, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0, 0, 0]'),
#  Text(0.9864864864864865, 0.4230769230769231, 'entropy = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0]'),
#  Text(0.8716216216216216, 0.6538461538461539, 'entropy = 0.0\nsamples = 75\nvalue = [0, 0, 75, 0]')]
